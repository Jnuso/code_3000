# %%
# packages
import pandas as pd
from mod02_build_bot_predictor import train_model

# %% [markdown]
# ### Define a function to extract predictions from the model

# %%
def predict_bot(df, model=None):
    """
    Predict whether each account is a bot (1) or human (0).
    """
    if model is None:
        model = train_model()

    preds = model.predict(df)
    return pd.Series(preds, index=df.index)

# %% [markdown]
# ### Define a function to evaluate model error

# %%
def confusion_matrix_and_metrics(y_true, y_pred):
    """
    Computes confusion matrix and common error rates for binary classification.

    Assumes labels:
      0 = negative class
      1 = positive class

    Returns:
      dict with:
        tn, fp, fn, tp
        misclassification_rate
        false_positive_rate
        false_negative_rate
    """
    tn = fp = fn = tp = 0

    for yt, yp in zip(y_true, y_pred):
        if yt == 0 and yp == 0:
            tn += 1
        elif yt == 0 and yp == 1:
            fp += 1
        elif yt == 1 and yp == 0:
            fn += 1
        elif yt == 1 and yp == 1:
            tp += 1
        else:
            raise ValueError("Labels must be 0 or 1")

    total = tn + fp + fn + tp

    misclassification_rate = (fp + fn) / total if total > 0 else 0.0
    false_positive_rate = fp / (fp + tn) if (fp + tn) > 0 else 0.0
    false_negative_rate = fn / (fn + tp) if (fn + tp) > 0 else 0.0

    return {
        "tp": tp,
        "tn": tn,
        "fp": fp,
        "fn": fn,
        "misclassification_rate": misclassification_rate,
        "false_positive_rate": false_positive_rate,
        "false_negative_rate": false_negative_rate,
    }

# %% [markdown]
# ### Load the data

# %%
TRAIN_PATH = "mod02_data/train.csv"
train = pd.read_csv(TRAIN_PATH)

TEST_PATH = "mod02_data/test.csv"
test = pd.read_csv(TEST_PATH)

# %% [markdown]
# ### Format the data by independent vs. dependent variables

# %%
X_train = train.drop(columns=["is_bot"])
y_train = train['is_bot']

X_test = test.drop(columns=["is_bot"])
y_test = test['is_bot']

# %% [markdown]
# ### Build the model on training data

# %%
model = train_model(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 model = train_model(X_train, y_train)
#
# File c:\Users\Jnuso\OneDrive\Documents\UCONN FALL 2026\CSE3000\code_3000\mod02_build_bot_predictor.py:20, in train_model(X, y, seed)
#       9 """
#      10 Build a GBM on given data
#      11 """
#      12 model = GradientBoostingClassifier(
#      13     learning_rate=0.005,
#      14     n_estimators=1000,
#    (...)     18     random_state=seed
#      19 )
# ---> 20 model.fit(X, y)
#      21 return model
#
# File c:\Users\Jnuso\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1329, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1324 partial_fit_and_fitted = (
#    1325     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1326 )
#    1328 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
#    1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Jnuso\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:492, in BaseEstimator._validate_params(self)
#     484 def _validate_params(self):
#     485     """Validate types and values of constructor parameters
#     486
#     487     The expected type and values must be defined in the `_parameter_constraints`
#    (...)    490     accepted constraints.
#     491     """
# --> 492     validate_parameter_constraints(
#     493         self._parameter_constraints,
#     494         self.get_params(deep=False),
#     495         caller_name=self.__class__.__name__,
#     496     )
#
# File c:\Users\Jnuso\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\_param_validation.py:98, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      92 else:
#      93     constraints_str = (
#      94         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      95         f" {constraints[-1]}"
#      96     )
# ---> 98 raise InvalidParameterError(
#      99     f"The {param_name!r} parameter of {caller_name} must be"
#     100     f" {constraints_str}. Got {param_val!r} instead."
#     101 )
#
# InvalidParameterError: The 'subsample' parameter of GradientBoostingClassifier must be a float in the range (0.0, 1.0]. Got 2 instead.

# %% [markdown]
# ### Get the model predictions on training and test data

# %%
y_pred_train = predict_bot(X_train, model)
y_pred_test = predict_bot(X_test, model)

# %% [markdown]
# ### Check results on the training set (data used to build the model)

# %%
confusion_matrix_and_metrics(y_train, y_pred_train)
# Out:
# {'tp': 331,
#  'tn': 2637,
#  'fp': 0,
#  'fn': 32,
#  'misclassification_rate': 0.010666666666666666,
#  'false_positive_rate': 0.0,
#  'false_negative_rate': 0.0881542699724518}

# %% [markdown]
# ### Check results on the test set (new data not yet seen by the model)

# %%
confusion_matrix_and_metrics(y_test, y_pred_test)
# Out:
# {'tp': 28,
#  'tn': 845,
#  'fp': 29,
#  'fn': 98,
#  'misclassification_rate': 0.127,
#  'false_positive_rate': 0.03318077803203661,
#  'false_negative_rate': 0.7777777777777778}

# %% [markdown]
# # Discussion Questions

# %% [markdown]
# ### Based on the misclassification rate of your model, discuss your confidence in the ability to predict a bot.

# %% [markdown]
# Type your answer here.

# %% [markdown]
# ### What are potential ramifications of false positives from the model?

# %% [markdown]
# Type your answer here.

# %% [markdown]
# ### What are potential ramifications of false negatives from the model?

# %% [markdown]
# Type your answer here.
